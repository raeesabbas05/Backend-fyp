# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split



# Load the dataset
data = pd.read_csv('/home/dexter/filtring/devops.csv')

# %%
data
# Out:
#           job_title        salary_range posted_date
# 0   DevOps Engineer   £60,000 - £95,000  2024-05-10
# 1   DevOps Engineer   £60,000 - £95,000  2024-04-28
# 2   DevOps Engineer   £60,000 - £95,000  2024-04-15
# 3   DevOps Engineer   £60,000 - £95,000  2024-03-30
# 4   DevOps Engineer   £60,000 - £95,000  2024-03-15
# ..              ...                 ...         ...
# 61  DevOps Engineer  £90,000 - £125,000  2021-09-15
# 62  DevOps Engineer  £90,000 - £125,000  2021-08-30
# 63  DevOps Engineer  £90,000 - £125,000  2021-08-15
# 64  DevOps Engineer  £90,000 - £125,000  2021-07-30
# 65  DevOps Engineer  £90,000 - £125,000  2021-07-15
#
# [66 rows x 3 columns]

# %%
# Select the relevant column (date)
data = data[['posted_date']]

# Convert 'posted_date' to datetime objects
data['posted_date'] = pd.to_datetime(data['posted_date'])

# Sort data by date
data = data.sort_values('posted_date')

# Create a numerical representation of the dates (days since a reference date)
reference_date = data['posted_date'].min()
data['days_since'] = (data['posted_date'] - reference_date).dt.days

# Check for NaN values in 'days_since'
print("NaN values in 'days_since':", data['days_since'].isnull().sum())

# Drop rows with NaN values in 'days_since'
data = data.dropna(subset=['days_since'])

# Use only the 'days_since' column for prediction
date_data = data['days_since'].values.reshape(-1, 1)

# Check for NaN values
print("NaN values in date_data before scaling:", np.isnan(date_data).sum())

# Normalize date data
scaler = MinMaxScaler(feature_range=(0, 1))
date_data = scaler.fit_transform(date_data)

# Check for NaN values after scaling
print("NaN values in date_data after scaling:", np.isnan(date_data).sum())

# If there are any NaN values after scaling, they need to be removed
nan_indices = np.isnan(date_data).flatten()
date_data = date_data[~nan_indices]

print("NaN values removed. New shape of date_data:", date_data.shape)
# Out:
# NaN values in 'days_since': 0
# NaN values in date_data before scaling: 0
# NaN values in date_data after scaling: 0
# NaN values removed. New shape of date_data: (66, 1)
# /tmp/ipykernel_23909/442334435.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['posted_date'] = pd.to_datetime(data['posted_date'])

# %%
# Prepare data for LSTM (create sequences)
look_back = 30  # Number of previous days to consider
X, Y = [], []
for i in range(look_back, len(date_data)):
    X.append(date_data[i - look_back:i])
    Y.append(date_data[i])

X = np.array(X)
Y = np.array(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Check for NaN values in X and Y
print("NaN values in X_train:", np.isnan(X_train).sum())
print("NaN values in Y_train:", np.isnan(Y_train).sum())
print("NaN values in X_test:", np.isnan(X_test).sum())
print("NaN values in Y_test:", np.isnan(Y_test).sum())
# Out:
# NaN values in X_train: 0
# NaN values in Y_train: 0
# NaN values in X_test: 0
# NaN values in Y_test: 0

# %%
# Create the LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=50, return_sequences=True, input_shape=(look_back, 1)),
    tf.keras.layers.LSTM(units=50),
    tf.keras.layers.Dense(1)
])

# Use a smaller learning rate to check for numerical stability
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# Train the model
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_data=(X_test, Y_test))

# Save the model
model.save('lstm_devops_prediction_model.h5')

# Plot the loss
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# /home/dexter/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.4199 - val_loss: 0.4086
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.3159 - val_loss: 0.2853
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.2213 - val_loss: 0.1753
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 0.1368 - val_loss: 0.0837
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0662 - val_loss: 0.0203
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0169 - val_loss: 4.9644e-04
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 3.6958e-04 - val_loss: 0.0325
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - loss: 0.0232 - val_loss: 0.0737
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0543 - val_loss: 0.0797
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0595 - val_loss: 0.0586
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0442 - val_loss: 0.0314
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0238 - val_loss: 0.0111
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0011 - val_loss: 4.9183e-04
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 3.4566e-04 - val_loss: 0.0047
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0034 - val_loss: 0.0107
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0079 - val_loss: 0.0162
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0120 - val_loss: 0.0199
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0148 - val_loss: 0.0214
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - loss: 0.0158 - val_loss: 0.0206
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0151 - val_loss: 0.0180
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0130 - val_loss: 0.0142
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.0069 - val_loss: 0.0059
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0016 - val_loss: 7.4905e-04
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 3.7759e-04 - val_loss: 2.1145e-04
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.3939e-04 - val_loss: 8.4825e-04
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0044 - val_loss: 0.0038
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 0.0017 - val_loss: 6.5671e-04
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 8.6263e-04 - val_loss: 2.7182e-04
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 3.4852e-04 - val_loss: 3.6986e-04
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 2.2762e-04 - val_loss: 8.2833e-04
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 4.1609e-04 - val_loss: 0.0015
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 7.7317e-04 - val_loss: 0.0021
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 9.4401e-04 - val_loss: 0.0012
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - loss: 6.3053e-04 - val_loss: 7.5903e-04
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 3.8039e-04 - val_loss: 4.3671e-04
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 2.3982e-04 - val_loss: 2.7336e-04
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 2.2044e-04 - val_loss: 2.5003e-04
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 2.9885e-04 - val_loss: 3.1443e-04
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 4.2650e-04 - val_loss: 4.0176e-04
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 5.4701e-04 - val_loss: 4.5768e-04
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 6.1492e-04 - val_loss: 4.5500e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 6.0914e-04 - val_loss: 3.9839e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 5.3649e-04 - val_loss: 3.1663e-04
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 4.2495e-04 - val_loss: 2.4729e-04
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 3.1067e-04 - val_loss: 2.2070e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.2451e-04 - val_loss: 2.4955e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.8291e-04 - val_loss: 3.2641e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.8543e-04 - val_loss: 4.2849e-04
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.1825e-04 - val_loss: 5.2663e-04
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 2.6104e-04 - val_loss: 5.9466e-04
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 2.9445e-04 - val_loss: 6.1655e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 3.0581e-04 - val_loss: 5.8947e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 2.9178e-04 - val_loss: 5.2288e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 2.5780e-04 - val_loss: 4.3432e-04
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 2.1497e-04 - val_loss: 3.4355e-04
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1.7569e-04 - val_loss: 2.6692e-04
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.4949e-04 - val_loss: 2.1350e-04
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.4027e-04 - val_loss: 1.8405e-04
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.4571e-04 - val_loss: 1.7272e-04
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.5896e-04 - val_loss: 1.7067e-04
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.7159e-04 - val_loss: 1.7002e-04
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.7689e-04 - val_loss: 1.6665e-04
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.7203e-04 - val_loss: 1.6090e-04
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1.5844e-04 - val_loss: 1.5627e-04
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 1.4065e-04 - val_loss: 1.5693e-04
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 1.2402e-04 - val_loss: 1.6539e-04
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.1265e-04 - val_loss: 1.8110e-04
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.0807e-04 - val_loss: 2.0057e-04
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.0910e-04 - val_loss: 2.1864e-04
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1280e-04 - val_loss: 2.3032e-04
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1.1584e-04 - val_loss: 2.3238e-04
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1581e-04 - val_loss: 2.2426e-04
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.1190e-04 - val_loss: 2.0796e-04
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.0498e-04 - val_loss: 1.8715e-04
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 9.6969e-05 - val_loss: 1.6588e-04
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.9932e-05 - val_loss: 1.4736e-04
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 8.5282e-05 - val_loss: 1.3329e-04
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 8.3321e-05 - val_loss: 1.2377e-04
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 8.3294e-05 - val_loss: 1.1779e-04
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 8.3855e-05 - val_loss: 1.1403e-04
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 8.3694e-05 - val_loss: 1.1146e-04
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 8.2064e-05 - val_loss: 1.0973e-04
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.8984e-05 - val_loss: 1.0900e-04
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 7.5109e-05 - val_loss: 1.0965e-04
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.1348e-05 - val_loss: 1.1178e-04
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.8441e-05 - val_loss: 1.1498e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Invert predictions to get actual date values
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform(Y_train.reshape(-1, 1))  # Reshape to 2D array
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D array

# Plot training and test predictions
plt.plot(Y_train, label='Actual Train')
plt.plot(train_predict, label='Predicted Train')
plt.plot(Y_test, label='Actual Test')
plt.plot(test_predict, label='Predicted Test')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('lstm_devops_prediction_model.h5')

# Recompile the model with the same loss and optimizer
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Predict the next 30 days
future_days = 30
look_back = 30  # This should match the look_back value used during training
last_sequence = date_data[-look_back:]  # Get the last sequence to predict the next day

future_predictions = []
for _ in range(future_days):
    next_prediction = model.predict(last_sequence.reshape(1, look_back, 1))
    future_predictions.append(next_prediction[0, 0])
    # Update the last sequence with the new prediction
    last_sequence = np.append(last_sequence[1:], next_prediction)

# Invert the predictions to get actual date values
future_predictions = np.array(future_predictions).reshape(-1, 1)
future_predictions = scaler.inverse_transform(future_predictions)

# Generate future dates
last_date = data['posted_date'].max()
future_dates = pd.date_range(last_date, periods=future_days + 1, inclusive='right')

# Plot the future predictions
plt.figure(figsize=(10, 6))
plt.plot(data['posted_date'], data['days_since'], label='Original Data')
plt.plot(future_dates, future_predictions, label='Future Predictions')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Days Since Reference Date')
plt.title('Future Predictions')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
